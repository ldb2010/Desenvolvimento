# %% [markdown]
# Aqui escreve texto

# %%
print("HEllo WOrd")
# Out:
# HEllo WOrd

# %%
import pandas as pd

# %% [markdown]
# Agora vou subir o EXEL

# %%
base = pd.read_excel("Resposta_Musical.xlsx")
base.head(10)
# Out:
#    ID_Aluno Genero_Musical
# 0         1            Pop
# 1         2         Gospel
# 2         3     Eletrônica
# 3         4          K-pop
# 4         5         Reggae
# 5         6            MPB
# 6         7            Rap
# 7         8     Eletrônica
# 8         9         Pagode
# 9        10         Gospel
